# %%
import torch
import torchvision
# import
import os
import pickle
import numpy as np
import PIL.Image

import scipy.io as sio
from datetime import datetime
import sys


sys.path.append('../model')
from resnet3d import resnet, mean
                
sys.path.append('../cnn_preferred')
from utils import normalise_img, clip_extreme_pixel, save_video, normalise_vid
from activation_maximization import generate_preferred

# %%
net = resnet.resnet50(num_classes=400, shortcut_type='B', sample_size=112, sample_duration=16)
net = torch.nn.DataParallel(net, device_ids=None)
param_file = os.path.join('../model','resnet3d', 'resnet-50-kinetics.pth')
param = torch.load(param_file, map_location='cpu')
net.load_state_dict(param['state_dict'])
net.eval()
# Out:
# ../model/resnet3d/resnet.py:159: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   m.weight = nn.init.kaiming_normal(m.weight, mode='fan_out')
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv3d(3, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool3d(kernel_size=(3, 3, 3), stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (4): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (5): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (avgpool): AvgPool3d(kernel_size=(1, 4, 4), stride=1, padding=0)
#     (fc): Linear(in_features=2048, out_features=400, bias=True)
#   )
# )

# %%
img_mean = np.float32([104, 117, 123])
img_std = np.float32([1,1,1])

# image
img_mean=np.array([0.485, 0.456, 0.406],dtype=np.float),
img_std = np.array([0.229,0.224,0.225])

img_mean = mean.get_mean(1)
img_std = mean.get_std(1)

# %%
img_std
# Out:
# [38.7568578, 37.88248729, 40.02898126]

# %%
#save_dir
save_dir = '../result'
save_folder = 'jupyter_demo_torch_resnet3D_TV_norm_all'#__file__.split('.')[0]
save_folder = save_folder + '_' + datetime.now().strftime('%Y%m%dT%H%M%S')
save_path = os.path.join(save_dir,save_folder)
os.makedirs(save_path, exist_ok=True)

# %%
def hook(module, input, output):
    outputs.append(output.clone())

# %%
# initial image for the optimization
fr, h, w = 16, 112,112

initial_input = np.random.randint(0, 256, (fr, h,w,3))

# %%
net
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv3d(3, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool3d(kernel_size=(3, 3, 3), stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (4): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (5): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#         (downsample): Sequential(
#           (0): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (iden): MyIdentity()
#       )
#     )
#     (avgpool): AvgPool3d(kernel_size=(1, 4, 4), stride=1, padding=0)
#     (fc): Linear(in_features=2048, out_features=400, bias=True)
#   )
# )

# %%
target_layer = "net.layer1[2].conv3"
target_layer = "net.module.conv1"
target_layer = "net.module.layer4[0].bn3"
target_layer = "module.layer1[2].conv3"

# %%
#targetlayer
outputs = []
exec_str_list = [target_layer +".register_forward_hook(hook)"]
exec(exec_str_list[0])
exec("num_of_ch = "+target_layer+".weight.detach().numpy().shape[0]") #param_list[layer_value].shape[0]
num_of_img = 10
step = int(num_of_ch/num_of_img)
channel_list = range(0,num_of_ch,step)
ee = net(torch.Tensor(initial_input.transpose(3,0, 1, 2)[np.newaxis]))
feat_num = outputs[0].detach().numpy().shape

# %%
# options
opts = {
    'img_mean': img_mean,
    'img_std': img_std,
    'exec_code': exec_str_list, # exection code inside the function

    'iter_n': 200, # the total number of iterations for gradient descend

    'disp_every': 1, # display the information on the terminal for every n iterations

    'save_intermediate': True, # save the intermediate or not
    'save_intermediate_every': 10, # save the intermediate for every n iterations
    'save_intermediate_path': save_path, # the path to save the intermediate

    'lr_start': 1., # learning rate
    'lr_end': 1.,

    'momentum_start': 0.001, # gradient with momentum
    'momentum_end': 0.001,

    'decay_start': 0.001, # pixel decay for each iteration
    'decay_end': 0.001,

    'image_blur': True, # Use image smoothing or not
    'sigma_start': 2.5, # the size of the gaussian filter for image smoothing
    'sigma_end': 0.5,

    'image_jitter': True, # use image jittering during
    'jitter_size': 4,
    
    'use_p_norm_reg': False,
    'p': 2,

    'use_TV_norm_reg': False,
    'TVbeta1': 1, 
    'TVbeta2':1.2,

    'clip_small_norm': True,
    'clip_small_norm_every': 1,
    'n_pct_start': 5,
    'n_pct_end': 5,

    'clip_small_contribution': True,
    'clip_small_contribution_every': 1,
    'c_pct_start': 5,
    'c_pct_end':5,
    
    'input_size': (32, 112,112,3),
    #'input_size': (224,224,3),
    #'initial_input': None, # the initial image for the optimization (setting to None will use random noise as initial image)
    'initial_input': initial_input,
    }

# %%
for channel in channel_list[:2]:
    #
    print('')
    print('channel='+str(channel))
    print('')

    # target units
    feat_size = feat_num
    t_index = int(feat_size[2]/2)
    y_index = int(feat_size[3]/2) # the unit in the center of feature map
    x_index = int(feat_size[4]/2) # the unit in the center of feature map
    feature_mask = np.zeros(feat_size)
    feature_mask[0,channel,t_index,y_index,x_index] = 1

    # weights for the target units
    feature_weight = np.zeros(feat_size, dtype=np.float32)
    feature_weight[:] = 1.

    #
    preferred_vid = generate_preferred(net, feature_mask, feature_weight=feature_weight, **opts)

    # save the results
    save_name = 'preferred_img' + '_layer_' + str(layer) + '_channel_' + str(channel) + '.mat'
    sio.savemat(os.path.join(save_path,save_name),{'preferred_vid':preferred_vid})

    save_name = 'preferred_img' + '_layer_' + str(layer) + '_channel_' + str(channel) + '.avi'
    save_video(normalise_vid(clip_extreme_pixel(preferred_vid,pct=0.04)), save_name, save_path )
# Out:
# channel=0
#
# iter=1; mean(abs(feat))=0.000291529;
# iter=2; mean(abs(feat))=0.00715177;
# iter=3; mean(abs(feat))=0.00878274;
# iter=4; mean(abs(feat))=0.00414184;
# iter=5; mean(abs(feat))=0.011772;
# iter=6; mean(abs(feat))=0.00814653;
# iter=7; mean(abs(feat))=0.0129455;
# iter=8; mean(abs(feat))=0.0205809;
# iter=9; mean(abs(feat))=0.0183472;
# iter=10; mean(abs(feat))=0.018599;
# iter=11; mean(abs(feat))=0.0142927;
# iter=12; mean(abs(feat))=0.0252574;
# iter=13; mean(abs(feat))=0.019405;
# iter=14; mean(abs(feat))=0.0188842;
# iter=15; mean(abs(feat))=0.011177;
# iter=16; mean(abs(feat))=0.0181988;
# iter=17; mean(abs(feat))=0.0219473;
# iter=18; mean(abs(feat))=0.0245365;
# iter=19; mean(abs(feat))=0.0239923;
# iter=20; mean(abs(feat))=0.0204981;
# iter=21; mean(abs(feat))=0.0262748;
# iter=22; mean(abs(feat))=0.0314092;
# iter=23; mean(abs(feat))=0.0245367;
# iter=24; mean(abs(feat))=0.0339685;
# iter=25; mean(abs(feat))=0.0372935;
# iter=26; mean(abs(feat))=0.0267696;
# iter=27; mean(abs(feat))=0.0277009;
# iter=28; mean(abs(feat))=0.032285;
# iter=29; mean(abs(feat))=0.0414409;
# iter=30; mean(abs(feat))=0.0406512;
# iter=31; mean(abs(feat))=0.0366162;
# iter=32; mean(abs(feat))=0.033067;
# iter=33; mean(abs(feat))=0.0423763;
# iter=34; mean(abs(feat))=0.0362597;
# iter=35; mean(abs(feat))=0.0479885;
# iter=36; mean(abs(feat))=0.0383051;
# iter=37; mean(abs(feat))=0.0348415;
# iter=38; mean(abs(feat))=0.05019;
# iter=39; mean(abs(feat))=0.0533608;
# iter=40; mean(abs(feat))=0.051545;
# iter=41; mean(abs(feat))=0.0489295;
# iter=42; mean(abs(feat))=0.0539063;
# iter=43; mean(abs(feat))=0.0277395;
# iter=44; mean(abs(feat))=0.0432974;
# iter=45; mean(abs(feat))=0.0340879;
# iter=46; mean(abs(feat))=0.0411367;
# iter=47; mean(abs(feat))=0.0321777;
# iter=48; mean(abs(feat))=0.0564982;
# iter=49; mean(abs(feat))=0.0356926;
# iter=50; mean(abs(feat))=0.0482893;
# iter=51; mean(abs(feat))=0.0549193;
# iter=52; mean(abs(feat))=0.0290454;
# iter=53; mean(abs(feat))=0.0605456;
# iter=54; mean(abs(feat))=0.0505743;
# iter=55; mean(abs(feat))=0.0600603;
# iter=56; mean(abs(feat))=0.0710533;
# iter=57; mean(abs(feat))=0.0682517;
# iter=58; mean(abs(feat))=0.0699199;
# iter=59; mean(abs(feat))=0.0657652;
# iter=60; mean(abs(feat))=0.0260224;
# iter=61; mean(abs(feat))=0.0540438;
# iter=62; mean(abs(feat))=0.0661345;
# iter=63; mean(abs(feat))=0.0732213;
# iter=64; mean(abs(feat))=0.0799774;
# iter=65; mean(abs(feat))=0.0549113;
# iter=66; mean(abs(feat))=0.0679278;
# iter=67; mean(abs(feat))=0.0690418;
# iter=68; mean(abs(feat))=0.0735854;
# iter=69; mean(abs(feat))=0.0535502;
# iter=70; mean(abs(feat))=0.0704979;
# iter=71; mean(abs(feat))=0.0706962;
# iter=72; mean(abs(feat))=0.0948474;
# iter=73; mean(abs(feat))=0.074576;
# iter=74; mean(abs(feat))=0.0817756;
# iter=75; mean(abs(feat))=0.0772633;
# iter=76; mean(abs(feat))=0.0832862;
# iter=77; mean(abs(feat))=0.0622655;
# iter=78; mean(abs(feat))=0.0866837;
# iter=79; mean(abs(feat))=0.0788293;
# iter=80; mean(abs(feat))=0.0655465;
# iter=81; mean(abs(feat))=0.086786;
# iter=82; mean(abs(feat))=0.0986405;
# iter=83; mean(abs(feat))=0.0999968;
# iter=84; mean(abs(feat))=0.0641705;
# iter=85; mean(abs(feat))=0.084979;
# iter=86; mean(abs(feat))=0.0757793;
# iter=87; mean(abs(feat))=0.108204;
# iter=88; mean(abs(feat))=0.0889216;
# iter=89; mean(abs(feat))=0.10025;
# iter=90; mean(abs(feat))=0.115647;
# iter=91; mean(abs(feat))=0.0912826;
# iter=92; mean(abs(feat))=0.0682147;
# iter=93; mean(abs(feat))=0.119589;
# iter=94; mean(abs(feat))=0.111395;
# iter=95; mean(abs(feat))=0.117112;
# iter=96; mean(abs(feat))=0.07493;
# iter=97; mean(abs(feat))=0.0981631;
# iter=98; mean(abs(feat))=0.114768;
# iter=99; mean(abs(feat))=0.122073;
# iter=100; mean(abs(feat))=0.104155;
# iter=101; mean(abs(feat))=0.0974251;
# iter=102; mean(abs(feat))=0.125013;
# iter=103; mean(abs(feat))=0.127563;
# iter=104; mean(abs(feat))=0.130957;
# iter=105; mean(abs(feat))=0.0522017;
# iter=106; mean(abs(feat))=0.110662;
# iter=107; mean(abs(feat))=0.102606;
# iter=108; mean(abs(feat))=0.105545;
# iter=109; mean(abs(feat))=0.128317;
# iter=110; mean(abs(feat))=0.134536;
# iter=111; mean(abs(feat))=0.0951275;
# iter=112; mean(abs(feat))=0.148269;
# iter=113; mean(abs(feat))=0.106362;
# iter=114; mean(abs(feat))=0.108819;
# iter=115; mean(abs(feat))=0.0968478;
# iter=116; mean(abs(feat))=0.122154;
# iter=117; mean(abs(feat))=0.113082;
# iter=118; mean(abs(feat))=0.131973;
# iter=119; mean(abs(feat))=0.117775;
# iter=120; mean(abs(feat))=0.148895;
# iter=121; mean(abs(feat))=0.14272;
# iter=122; mean(abs(feat))=0.161663;
# iter=123; mean(abs(feat))=0.177805;
# iter=124; mean(abs(feat))=0.164118;
# iter=125; mean(abs(feat))=0.180634;
# iter=126; mean(abs(feat))=0.190127;
# iter=127; mean(abs(feat))=0.181999;
# iter=128; mean(abs(feat))=0.179055;
# iter=129; mean(abs(feat))=0.205238;
# iter=130; mean(abs(feat))=0.119868;
# iter=131; mean(abs(feat))=0.0924903;
# iter=132; mean(abs(feat))=0.144184;
# iter=133; mean(abs(feat))=0.164333;
# iter=134; mean(abs(feat))=0.17015;
# iter=135; mean(abs(feat))=0.115176;
# iter=136; mean(abs(feat))=0.181574;
# iter=137; mean(abs(feat))=0.163818;
# iter=138; mean(abs(feat))=0.162491;
# iter=139; mean(abs(feat))=0.162549;
# iter=140; mean(abs(feat))=0.207385;
# iter=141; mean(abs(feat))=0.236622;
# iter=142; mean(abs(feat))=0.15847;
# iter=143; mean(abs(feat))=0.185088;
# iter=144; mean(abs(feat))=0.190637;
# iter=145; mean(abs(feat))=0.179804;
# iter=146; mean(abs(feat))=0.1799;
# iter=147; mean(abs(feat))=0.211864;
# iter=148; mean(abs(feat))=0.201173;
# iter=149; mean(abs(feat))=0.261223;
# iter=150; mean(abs(feat))=0.238526;
# iter=151; mean(abs(feat))=0.101491;
# iter=152; mean(abs(feat))=0.214914;
# iter=153; mean(abs(feat))=0.157233;
# iter=154; mean(abs(feat))=0.160495;
# iter=155; mean(abs(feat))=0.216944;
# iter=156; mean(abs(feat))=0.257044;
# iter=157; mean(abs(feat))=0.251621;
# iter=158; mean(abs(feat))=0.305636;
# iter=159; mean(abs(feat))=0.21613;
# iter=160; mean(abs(feat))=0.288422;
# iter=161; mean(abs(feat))=0.294568;
# iter=162; mean(abs(feat))=0.250041;
# iter=163; mean(abs(feat))=0.2049;
# iter=164; mean(abs(feat))=0.265923;
# iter=165; mean(abs(feat))=0.325587;
# iter=166; mean(abs(feat))=0.187612;
# iter=167; mean(abs(feat))=0.314784;
# iter=168; mean(abs(feat))=0.364144;
# iter=169; mean(abs(feat))=0.251816;
# iter=170; mean(abs(feat))=0.231252;
# iter=171; mean(abs(feat))=0.286101;
# iter=172; mean(abs(feat))=0.329078;
# iter=173; mean(abs(feat))=0.288862;
# iter=174; mean(abs(feat))=0.252152;
# iter=175; mean(abs(feat))=0.303892;
# iter=176; mean(abs(feat))=0.384039;
# iter=177; mean(abs(feat))=0.314819;
# iter=178; mean(abs(feat))=0.341634;
# iter=179; mean(abs(feat))=0.307355;
# iter=180; mean(abs(feat))=0.297647;
# iter=181; mean(abs(feat))=0.384329;
# iter=182; mean(abs(feat))=0.193976;
# iter=183; mean(abs(feat))=0.328154;
# iter=184; mean(abs(feat))=0.360705;
# iter=185; mean(abs(feat))=0.420807;
# iter=186; mean(abs(feat))=0.329632;
# iter=187; mean(abs(feat))=0.348528;
# iter=188; mean(abs(feat))=0.293796;
# iter=189; mean(abs(feat))=0.273872;
# iter=190; mean(abs(feat))=0.44986;
# iter=191; mean(abs(feat))=0.368319;
# iter=192; mean(abs(feat))=0.308461;
# iter=193; mean(abs(feat))=0.292446;
# iter=194; mean(abs(feat))=0.443216;
# iter=195; mean(abs(feat))=0.505901;
# iter=196; mean(abs(feat))=0.353134;
# iter=197; mean(abs(feat))=0.276326;
# iter=198; mean(abs(feat))=0.485032;
# iter=199; mean(abs(feat))=0.583502;
# iter=200; mean(abs(feat))=0.40003;
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-412f92bc7b24> in <module>()
#      21
#      22     # save the results
# ---> 23     save_name = 'preferred_img' + '_layer_' + str(layer) + '_channel_' + str(channel) + '.mat'
#      24     sio.savemat(os.path.join(save_path,save_name),{'preferred_vid':preferred_vid})
#      25
#
# NameError: name 'layer' is not defined

# %%
# options
opts = {
    'img_mean': img_mean,
    'img_std': img_std,
    'exec_code': exec_str_list, # exection code inside the function

    'iter_n': 200, # the total number of iterations for gradient descend

    'disp_every': 1, # display the information on the terminal for every n iterations

    'save_intermediate': True, # save the intermediate or not
    'save_intermediate_every': 10, # save the intermediate for every n iterations
    'save_intermediate_path': save_path, # the path to save the intermediate

    'lr_start': 1., # learning rate
    'lr_end': 1.,

    'momentum_start': 0.001, # gradient with momentum
    'momentum_end': 0.001,

    'decay_start': 0.001, # pixel decay for each iteration
    'decay_end': 0.001,

    'image_blur': True, # Use image smoothing or not
    'sigma_start': 2.5, # the size of the gaussian filter for image smoothing
    'sigma_end': 0.5,

    'image_jitter': True, # use image jittering during
    'jitter_size': 32,
    
    'use_p_norm_reg': False,
    'p': 2,

    'use_TV_norm_reg': True,
    'TVbeta1': 1, 
    'TVbeta2':1.2,

    'clip_small_norm': True,
    'clip_small_norm_every': 1,
    'n_pct_start': 5,
    'n_pct_end': 5,

    'clip_small_contribution': True,
    'clip_small_contribution_every': 1,
    'c_pct_start': 5,
    'c_pct_end':5,
    
    'input_size': (32, 112,112,3),
    #'input_size': (224,224,3),
    #'initial_input': None, # the initial image for the optimization (setting to None will use random noise as initial image)
    'initial_input': initial_input,
    }

# %%
for channel in channel_list[-2:]:
    #
    print('')
    print('channel='+str(channel))
    print('')

    # target units
    feat_size = feat_num
     # the unit in the center of feature map
    feature_mask = np.zeros(feat_size)
    feature_mask[0,channel] = 1

    # weights for the target units
    feature_weight = np.zeros(feat_size, dtype=np.float32)
    feature_weight[:] = 1.



    #
    preferred_vid = generate_preferred(net, feature_mask, feature_weight=feature_weight, **opts)

    # save the results
    save_name = 'preferred_img' + '_layer_' + str(target_layer) + '_channel_' + str(channel) + '.mat'
    sio.savemat(os.path.join(save_path,save_name),{'preferred_vid':preferred_vid})

    save_name = 'preferred_img' + '_layer_' + str(target_layer) + '_channel_' + str(channel) + '.avi'
    save_video(normalise_vid(clip_extreme_pixel(preferred_vid,pct=0.04)), save_name, save_path )
# Out:
# channel=225
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-289eb7d21037> in <module>()
#      18
#      19     #
# ---> 20     preferred_vid = generate_preferred(net, feature_mask, feature_weight=feature_weight, **opts)
#      21
#      22     # save the results
#
# TypeError: generate_preferred() got multiple values for argument 'exec_code'

# %%
target_layer
# Out:
# 'net.module.fc'
